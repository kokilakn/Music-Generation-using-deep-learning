# %%
from music21 import *
Part=[]

# %%
def read_midi(file):
    
    print("Loading Music File:",file)
    
    notes=[]
    notes_to_parse = None
    
    #parsing a midi file
    midi = converter.parse(file)
  
    #grouping based on different instruments
    s2 = instrument.partitionByInstrument(midi)
    
    #Looping over all the instruments
    for part in s2.parts:
        result_str = ""
        string=((str(part)))
        for i in range(0, len(str(part))):
            if i > 20 and i < (len(str(part))-1):
                result_str = result_str + string[i]
        Part.append(result_str)
        print(result_str)
    return np.array(notes)

# %%
#for listing down the file names
import os

#Array Processing
import numpy as np

#specify the path
path='/Users/kokilareddy/Downloads/midis/Guitar_midkar.com_MIDIRip/jazz/'

#read all the filenames
files=[i for i in os.listdir(path) if i.endswith(".mid")]
#reading each midi file
([read_midi(path+i) for i in files])
# Out:
# Loading Music File: /Users/kokilareddy/Downloads/midis/Guitar_midkar.com_MIDIRip/jazz/the_color_of_my_love_jlh.mid
# Bass
# Fretless Bass
# Piano
# Acoustic Guitar
# StringInstrument
# Sampler
# Loading Music File: /Users/kokilareddy/Downloads/midis/Guitar_midkar.com_MIDIRip/jazz/indian_summer_mw.mid
# Bass / Acoustic bass
# Acoustic Bass
# Piano / Rhodes piano
# Piano
# Melody / Rhodes piano
# Electric Guitar
# Acoustic Guitar
# StringInstrument
# Loading Music File: /Users/kokilareddy/Downloads/midis/Guitar_midkar.com_MIDIRip/jazz/the_blue_chip_bop-acoustic-alchemy_bb2.mid
# Piano
# Bass
# Electric Guitar
# StringInstrument
# Sampler
# Piano Solo
# Acoustic Guitar
# Crash Cymbals
# Agogo Bells
# Congas
# Timbales
# Loading Music File: /Users/kokilareddy/Downloads/midis/Guitar_midkar.com_MIDIRip/jazz/bossa_nova_usa_dwb.mid
# Acoustic Bass
# Piano
# Fretless Bass
# Loading Music File: /Users/kokilareddy/Downloads/midis/Guitar_midkar.com_MIDIRip/jazz/too_young-kar_gl.mid
#
# Piano
# ...

# %%
Part
# Out:
# ['Bass',
#  'Fretless Bass',
#  'Piano',
#  'Acoustic Guitar',
#  'StringInstrument',
#  'Sampler',
#  'Bass / Acoustic bass',
#  'Acoustic Bass',
#  'Piano / Rhodes piano',
#  'Piano',
#  'Melody / Rhodes piano',
#  'Electric Guitar',
#  'Acoustic Guitar',
#  'StringInstrument',
#  'Piano',
#  'Bass',
#  'Electric Guitar',
#  'StringInstrument',
#  'Sampler',
#  'Piano Solo',
#  'Acoustic Guitar',
#  'Crash Cymbals',
#  'Agogo Bells',
#  'Congas',
#  'Timbales',
#  'Acoustic Bass',
#  'Piano',
#  'Fretless Bass',
#  '',
#  'Piano',
#  'Electric Bass',
#  'Recorder',
#  'Acoustic Guitar',
#  'StringInstrument',
#  'Violin',
#  'piano',
#  'Piano',
#  'piano 2',
#  'bass',
#  'Acoustic Bass',
#  'trumpet',
#  'Trumpet',
#  'Brass',
#  'trombone',
#  'Trombone',
#  'tenor',
#  'Tenor Saxophone',
#  'clarinet',
#  'Clarinet',
#  'Celesta',
#  'piano 1',
#  'Piano',
#  'piano 2',
#  'piano 3',
#  'piano 4',
#  'pizz str bass',
#  'StringInstrument',
#  'E-flat Alto Saxes',
# ...

# %%
import collections 
counts = collections.Counter(Part)
new_list = sorted(Part, key=lambda x: -counts[x])

# %%
counts
# Out:
# Counter({'Bass': 69,
#          'Fretless Bass': 47,
#          'Piano': 227,
#          'Acoustic Guitar': 78,
#          'StringInstrument': 95,
#          'Sampler': 49,
#          'Bass / Acoustic bass': 9,
#          'Acoustic Bass': 142,
#          'Piano / Rhodes piano': 4,
#          'Melody / Rhodes piano': 1,
#          'Electric Guitar': 93,
#          'Piano Solo': 1,
#          'Crash Cymbals': 1,
#          'Agogo Bells': 1,
#          'Congas': 4,
#          'Timbales': 1,
#          '': 103,
#          'Electric Bass': 57,
#          'Recorder': 3,
#          'Violin': 34,
#          'piano': 9,
#          'piano 2': 14,
#          'bass': 7,
#          'trumpet': 1,
#          'Trumpet': 76,
#          'Brass': 29,
#          'trombone': 1,
#          'Trombone': 50,
#          'tenor': 1,
#          'Tenor Saxophone': 55,
#          'clarinet': 1,
#          'Clarinet': 21,
#          'Celesta': 12,
#          'piano 1': 12,
#          'piano 3': 12,
# ...

# %%
new_list
# Out:
# ['Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
#  'Piano',
# ...

# %%
import sounddevice as sd
import numpy as np
from scipy.io.wavfile import write 
# import wavio as wv
import scipy.io.wavfile as wav

fs=44100
duration = 5  # seconds
myrecording = sd.rec(duration * fs, samplerate=fs, channels=2,dtype='float64')
print("Recording Audio")
sd.wait()
print("Audio recording complete , Play Audio")
sd.play(myrecording, fs)
write("recording0.wav", freq, myrecording)
sd.wait()
print ("Play Audio Complete")
# Out:
# Recording Audio
# Audio recording complete , Play Audio
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ff6d0536d304> in <module>
#      12 print("Audio recording complete , Play Audio")
#      13 sd.play(myrecording, fs)
# ---> 14 write("recording0.wav", freq, myrecording)
#      15 sd.wait()
#      16 print ("Play Audio Complete")
#
# NameError: name 'freq' is not defined
